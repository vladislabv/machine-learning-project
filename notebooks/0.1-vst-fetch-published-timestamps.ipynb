# %%
import os
import dotenv
import requests
import numpy as np
import pandas as pd

# %%
# Load environment variables
project_dir = os.path.join(os.path.abspath(''), os.pardir)
dotenv_path = os.path.join(project_dir, '.env')

dotenv.load_dotenv(dotenv_path)
# Out:
# True

# %%
df = pd.read_csv(os.path.join(os.getenv('DATA_PATH'), 'data_cols_extended.csv'), low_memory=False, keep_default_na = True, na_values=['\\N', 0, 0.0, '0', '0.0'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87927 entries, 0 to 87926
# Data columns (total 73 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Projekt                        87927 non-null  object
#  1   Campaign                       87927 non-null  object
#  2   Subcampaign                    87927 non-null  object
#  3   Paid / Organic                 87927 non-null  object
#  4   Campaign Name                  1 non-null      object
#  5   FB Ad Name                     0 non-null      float64
#  6   Company                        87927 non-null  object
#  7   Channel                        87927 non-null  object
#  8   Subchannel                     87927 non-null  object
#  9   Content Type                   87927 non-null  object
#  10  DarkPublic                     87927 non-null  object
#  11  Content ID                     87927 non-null  object
#  12  share.id                       87899 non-null  object
#  13  Video                          0 non-null      float64
#  14  Permalink                      87927 non-null  object
#  15  Message Text                   87926 non-null  object
#  16  Date                           87926 non-null  object
#  17  Country                        87926 non-null  object
#  18  Average Percentage Viewed      0 non-null      float64
#  19  Budget                         0 non-null      float64
#  20  Impressions Total              87926 non-null  float64
#  21  Impressions Paid               1 non-null      float64
#  22  Impressions Unpaid             87925 non-null  float64
#  23  WS Impressions Social          0 non-null      float64
#  24  WS Impressions Referral        0 non-null      float64
#  25  WS Impressions Paid Search     0 non-null      float64
#  26  WS Impressions Organic Search  0 non-null      float64
#  27  WS Impressions Email           0 non-null      float64
#  28  WS Impressions Display         0 non-null      float64
#  29  WS Impressions Direct          0 non-null      float64
#  30  WS Impressions Other           0 non-null      float64
#  31  Comments                       3839 non-null   float64
#  32  Likes                          32012 non-null  float64
#  33  Shares                         8514 non-null   float64
#  34  Link Clicks                    0 non-null      float64
#  35  Other Engagements              35456 non-null  float64
#  36  Saves                          0 non-null      float64
#  37  Video Starts                   0 non-null      float64
#  38  Video length                   0 non-null      float64
#  39  Page Likes                     0 non-null      float64
#  40  ThruPlays                      0 non-null      float64
#  41  95 prozent Views               0 non-null      float64
#  42  25 prozent Views               0 non-null      float64
#  43  50 prozent Views               0 non-null      float64
#  44  75 prozent Views               0 non-null      float64
#  45  Bounces                        0 non-null      float64
#  46  Unsubscribers                  0 non-null      float64
#  47  30 sec on page                 0 non-null      float64
#  48  Video01                        0 non-null      float64
#  49  VideoNonVideo                  87926 non-null  object
#  50  30 sec Views                   0 non-null      float64
#  51  Engagements Paid               0 non-null      float64
#  52  Engagements                    42429 non-null  float64
#  53  Engagements w/o TrueViews      42429 non-null  float64
#  54  Multiplier                     32383 non-null  float64
#  55  Image URL                      2441 non-null   object
#  56  codiert                        0 non-null      float64
#  57  Post Date                      87926 non-null  object
#  58  Days since Post Date           83537 non-null  float64
#  59  Inbound                        0 non-null      float64
#  60  Outbound                       0 non-null      float64
#  61  Navigation                     0 non-null      float64
#  62  Sign-Ups                       0 non-null      float64
#  63  Anfragen an Vertriebspartner   0 non-null      float64
#  64  Shopping Carts                 0 non-null      float64
#  65  Orders                         0 non-null      float64
#  66  Taps Back                      0 non-null      float64
#  67  Replies                        0 non-null      float64
#  68  fanpage_id                     87926 non-null  float64
#  69  contribution_id                87926 non-null  float64
#  70  division_id                    87926 non-null  float64
#  71  all_hashtags                   74820 non-null  object
#  72  has_any_hashtag                87926 non-null  object
# dtypes: float64(52), object(21)
# memory usage: 49.0+ MB

# %%
df_post_dates = pd.read_csv(os.path.join(os.getenv('DATA_EXT_PATH'), 'found_timestamps.csv'))
df_post_dates
# Out:
#                                       ID                  Post Ts
# 0     urn:li:ugcPost:7080032059519373312  2023-06-29 05:59:43.870
# 1       urn:li:share:7049282071755694080  2023-04-05 09:30:15.391
# 2       urn:li:share:7057277321598132224  2023-04-27 11:00:31.505
# 3       urn:li:share:7021364524641394688  2023-01-18 07:35:53.486
# 4       urn:li:share:7089510852810166272  2023-07-25 09:45:04.695
# ...                                  ...                      ...
# 4328    urn:li:share:7072474322124120064  2023-06-08 09:27:58.783
# 4329  urn:li:ugcPost:7069272909654974464  2023-05-30 13:26:43.492
# 4330    urn:li:share:7068926451479191553  2023-05-29 14:30:00.470
# 4331    urn:li:share:7032333183689842688  2023-02-17 14:01:25.618
# 4332    urn:li:share:7057269152763265026  2023-04-27 10:28:03.872
#
# [4333 rows x 2 columns]

# %%
df_cut = df.loc[:,
[
    'Content ID', 'share.id','Permalink',
    'Message Text', 'Date', 'Impressions Unpaid', 'Comments', 'Likes',
    'Shares', 'Other Engagements', 'Engagements', 'Image URL',
    'Post Date', 'Days since Post Date', 'fanpage_id', 'all_hashtags'
]]

# %%
df_cut = df_cut[~df_cut['share.id'].isna()]
df_cut = df_cut[~df_cut['Message Text'].isna()]
df_cut = df_cut[~df_cut['Impressions Unpaid'].isna()]

# %%
test1 = df_cut[df_cut['Message Text'].str.match(r"no text \(\d{2}.\d{2}.\d{2}\)")]['share.id'].unique()
# check if some message text can be replaced instead of dummy texts
df_cut[df_cut['share.id'].isin(test1) & (~df_cut['Message Text'].str.match(r"no text \(\d{2}.\d{2}.\d{2}\)"))]
# Out:
# Empty DataFrame
# Columns: [Content ID, share.id, Permalink, Message Text, Date, Impressions Unpaid, Comments, Likes, Shares, Other Engagements, Engagements, Image URL, Post Date, Days since Post Date, fanpage_id, all_hashtags]
# Index: []

# %%
df_cut = df_cut[~df_cut['Message Text'].str.match(r"no text \(\d{2}.\d{2}.\d{2}\)")]

# %%
df_cut.loc[:, 'ID'] = df_cut['share.id']

# %%
df_cut.loc[:, 'Post Date'] = pd.to_datetime(df_cut['Post Date'])

# %%
df_cut.loc[:, 'Date'] = pd.to_datetime(df_cut['Date'])

# %%
df_cut.loc[:, 'has_any_image'] = np.where(df_cut['Image URL'].str.len() > 0, True, False)

# %%
df_cut.loc[:, 'hashtags'] = df_cut['all_hashtags'].str.replace('#', '').apply(lambda x: ','.join(filter(len, x.split())) if isinstance(x, str) else x)

# %%
df_cut.loc[:, 'has_any_hashtag'] = np.where(df_cut['hashtags'].str.len() > 0, True, False)

# %%
df_cut.loc[:, 'dow_posted'] = pd.to_datetime(df_cut['Post Date']).dt.day_name()

# %%
df_cut.loc[:, 'post_len'] = df_cut['Message Text'].str.len()

# %%
# Use if provided timestamps not available // TOKEN needed
# from datetime import datetime
# from linkedin_api.clients.restli.client import RestliClient

# restli_client = RestliClient()
# posts = df_cut.ID.unique()
# zips = []
# created_ats = []
# split_by_size = lambda x, size: np.split( x, np.arange(size, len(x), size) )
# chunks = split_by_size(x=posts, size=100)
# for chunk in chunks:
#     resp = restli_client.batch_get(
#       resource_path="/posts",
#       ids=list(chunk),
#       access_token=os.getenv('API_LI_TOKEN'),
#       version_string="202304"
#     )
#     print(resp)
#     li_items = resp.results.items()
#     tss = [datetime.fromtimestamp(i[1].get('createdAt', 0)/1000) for i in li_items]
#     ids = [i[0] for i in li_items]
#     res = zip(ids, tss)
#     zips.append(res)
#     created_ats.extend(list(res))
# df_post_dates = pd.DataFrame(created_ats, columns =['ID', 'Post Ts'])

# %%
df_cut_with_ts = pd.merge(
    df_cut,
    df_post_dates,
    on = ['ID'],
    how = 'left'
)

# %%
df_cut_with_ts.loc[df_cut_with_ts['Post Ts'].isna(), 'Post Ts'] = pd.to_datetime(df_cut_with_ts['Post Date'])

# %%
df_cut_with_ts.loc[:, 'hm_posted'] = pd.to_datetime(df_cut_with_ts['Post Ts'], errors='coerce').dt.strftime('%H:%M')

# %%
df_cut_with_ts.loc[:, 'hour_posted'] = pd.to_datetime(df_cut_with_ts['Post Ts'], errors='coerce').dt.strftime('%H').astype('int')

# %%
df_cut_with_ts.loc[df_cut_with_ts['Days since Post Date'].isna(), 'Days since Post Date'] = 0

# %%
df_cut_with_ts.head()
# Out:
#                             Content ID                            share.id  \
# 0  urn:li:activity:7049687222605754368    urn:li:share:7049687219682299905
# 1  urn:li:activity:7079078882049478656    urn:li:share:7079078881395167233
# 2  urn:li:activity:7054408338465300481    urn:li:share:7054408337148325888
# 3   urn:li:ugcPost:7069950389063667712  urn:li:ugcPost:7069950389063667712
# 4  urn:li:activity:7057277322424410112    urn:li:share:7057277321598132224
#
#                                            Permalink  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...
# 1  https://www.linkedin.com/feed/update/urn:li:ac...
# 2  https://www.linkedin.com/feed/update/urn:li:ac...
# 3  https://www.linkedin.com/feed/update/urn:li:ug...
# 4  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                                         Message Text                 Date  \
# 0  2023 – the year of #ChatGPT and Co. 🤯 Will gen...  2023-04-18 00:00:00
# 1  Smart Mechatronix: the perfect ready-to-instal...  2023-07-03 00:00:00
# 2  We love oranges so much, we want to extract as...  2023-04-30 00:00:00
# 3  “Inclusion starts with I” – @[Nadine Ilgenstei...  2023-06-18 00:00:00
# 4  MediaMarktSaturn geht den nächsten digitalen S...  2023-05-19 00:00:00
#
#    Impressions Unpaid  Comments  Likes  Shares  Other Engagements  ...  \
# 0               186.0       NaN    NaN     NaN                1.0  ...
# 1                 7.0       NaN    NaN     NaN                NaN  ...
# 2              1191.0       1.0   14.0     NaN               32.0  ...
# 3               788.0       NaN    4.0     NaN               73.0  ...
# 4               195.0       NaN    1.0     NaN                3.0  ...
#
#                                         all_hashtags  \
# 0  #AI #ArtificialIntelligence #ChatGPT #Generati...
# 1                                       #Mechatronix
# 2  #foodindustry #foodingredients #orange #orange...
# 3             #Diversity #Inclusion #WeAreSchaeffler
# 4  #experiencechampion #Retail #Service #Sustaina...
#
#                                    ID has_any_image  \
# 0    urn:li:share:7049687219682299905         False
# 1    urn:li:share:7079078881395167233         False
# 2    urn:li:share:7054408337148325888         False
# 3  urn:li:ugcPost:7069950389063667712         False
# 4    urn:li:share:7057277321598132224         False
#
#                                             hashtags  has_any_hashtag  \
# 0  AI,ArtificialIntelligence,ChatGPT,GenerativeAI...             True
# 1                                        Mechatronix             True
# 2  foodindustry,foodingredients,orange,orangeflav...             True
# 3                Diversity,Inclusion,WeAreSchaeffler             True
# 4  experiencechampion,Retail,Service,Sustainabili...             True
#
#   dow_posted post_len                  Post Ts hm_posted  hour_posted
# 0   Thursday      730  2023-04-06 12:20:10.694     12:20           12
# 1     Monday      284  2023-06-26 14:52:08.375     14:52           14
# 2  Wednesday      899  2023-04-19 13:00:12.335     13:00           13
# 3     Monday      803  2023-06-01 10:18:46.279     10:18           10
# 4   Thursday      773  2023-04-27 11:00:31.505     11:00           11
#
# [5 rows x 25 columns]

# %%
df_cut_final = df_cut_with_ts.loc[:, 
[
    'Message Text', 'Date',
    'Impressions Unpaid', 'Comments', 'Likes', 'Shares',
    'Other Engagements', 'Engagements',
    'Days since Post Date', 'fanpage_id',
    'ID', 'has_any_image', 'hashtags', 'has_any_hashtag', 'dow_posted',
    'post_len', 'Post Ts', 'hm_posted', 'hour_posted'
]].rename(columns={
    'Impressions Unpaid': 'Impressions',
    'Days since Post Date': 'days_since_posted',
    'Post Ts': 'timestamp_posted'
})

# %%
df_cut_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85904 entries, 0 to 85903
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Message Text       85904 non-null  object
#  1   Date               85904 non-null  object
#  2   Impressions        85904 non-null  float64
#  3   Comments           3817 non-null   float64
#  4   Likes              31898 non-null  float64
#  5   Shares             8472 non-null   float64
#  6   Other Engagements  34749 non-null  float64
#  7   Engagements        41702 non-null  float64
#  8   days_since_posted  85904 non-null  float64
#  9   fanpage_id         85904 non-null  float64
#  10  ID                 85904 non-null  object
#  11  has_any_image      85904 non-null  bool
#  12  hashtags           74792 non-null  object
#  13  has_any_hashtag    85904 non-null  bool
#  14  dow_posted         85904 non-null  object
#  15  post_len           85904 non-null  int64
#  16  timestamp_posted   85904 non-null  object
#  17  hm_posted          85904 non-null  object
#  18  hour_posted        85904 non-null  int32
# dtypes: bool(2), float64(8), int32(1), int64(1), object(7)
# memory usage: 11.0+ MB

# %%
df_cut_final.head()
# Out:
#                                         Message Text                 Date  \
# 0  2023 – the year of #ChatGPT and Co. 🤯 Will gen...  2023-04-18 00:00:00
# 1  Smart Mechatronix: the perfect ready-to-instal...  2023-07-03 00:00:00
# 2  We love oranges so much, we want to extract as...  2023-04-30 00:00:00
# 3  “Inclusion starts with I” – @[Nadine Ilgenstei...  2023-06-18 00:00:00
# 4  MediaMarktSaturn geht den nächsten digitalen S...  2023-05-19 00:00:00
#
#    Impressions  Comments  Likes  Shares  Other Engagements  Engagements  \
# 0        186.0       NaN    NaN     NaN                1.0          1.0
# 1          7.0       NaN    NaN     NaN                NaN          NaN
# 2       1191.0       1.0   14.0     NaN               32.0         47.0
# 3        788.0       NaN    4.0     NaN               73.0         77.0
# 4        195.0       NaN    1.0     NaN                3.0          4.0
#
#    days_since_posted  fanpage_id                                  ID  \
# 0               12.0    157764.0    urn:li:share:7049687219682299905
# 1                7.0     56825.0    urn:li:share:7079078881395167233
# 2               11.0      2269.0    urn:li:share:7054408337148325888
# 3                6.0       118.0  urn:li:ugcPost:7069950389063667712
# 4               22.0    155056.0    urn:li:share:7057277321598132224
#
#    has_any_image                                           hashtags  \
# 0          False  AI,ArtificialIntelligence,ChatGPT,GenerativeAI...
# 1          False                                        Mechatronix
# 2          False  foodindustry,foodingredients,orange,orangeflav...
# 3          False                Diversity,Inclusion,WeAreSchaeffler
# 4          False  experiencechampion,Retail,Service,Sustainabili...
#
#    has_any_hashtag dow_posted  post_len         timestamp_posted hm_posted  \
# 0             True   Thursday       730  2023-04-06 12:20:10.694     12:20
# 1             True     Monday       284  2023-06-26 14:52:08.375     14:52
# 2             True  Wednesday       899  2023-04-19 13:00:12.335     13:00
# 3             True     Monday       803  2023-06-01 10:18:46.279     10:18
# 4             True   Thursday       773  2023-04-27 11:00:31.505     11:00
#
#    hour_posted
# 0           12
# 1           14
# 2           13
# 3           10
# 4           11

# %%
df_cut_final.to_csv(os.path.join(os.getenv('SAVE_INTERIM_FILES_PATH'), 'data_interim_new_features.csv'), index=False, encoding='utf-8')
